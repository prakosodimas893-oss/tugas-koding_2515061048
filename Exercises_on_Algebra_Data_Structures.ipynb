# %%
#selesaikan soal berikut
import numpy as np
x = np.array([[25],[2] ,[-3],[-23]])
x_t=x.T
print(f"hasil dari transpose vektor adalah {x}")
# Out:
# hasil dari transpose vektor adalah[[ 25]
#  [  2]
#  [ -3]
#  [-23]]
