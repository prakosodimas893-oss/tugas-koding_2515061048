# %%
# 1 buat variabel skalar x dan simpan suatu nilai skalar
x = 480
print(f"tipe data saklar x adalah :{x}")

# %%
# tampilkan tipe data dari x
type(x)
print(f"tipe data saklar x adalah :{type(x)}")
# Out:
# tipe data saklar x adalah :<class 'int'>

# %%
#  buat variabel skalar y dan simpan suatu nilai skalar

y = 840
print(f"variabel skalar y adaah : {y}")
# Out:
# variabel skalar y adaah : 840

# %%
# tampilkan tipe data dari y
type(y)
print(f"tipe data saklar x adalah :{type(y)}")
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 1320

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 480.0

# %%
# jumlahkan x_float dengan y

float_sum = x_float + y
float_sum
# Out:
# 1320.0

# %%
# tampilkan tipe data dari x_float
type(float_sum)
# Out:
# float

# %%
# 2 lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
#  buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(48.0)

# %%
# tampilkan tipe data dari x
dtype_tf = (x_tf)
dtype_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=48.0>

# %%
#  buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(84.0)

# %%
# tampilkan tipe data dari y
dtype_tf = (y_tf)
dtype_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=84.0>

# %%
# jumlahkan x+y
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=132.0>

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = tf.Variable(84.0)

# %%
# jumlahkan x_float dengan y
tf_sum=tf.add(x_float, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=168.0>

# %%
# tampilkan tipe data dari x_float
dtype_tf = (x_float)
dtype_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=84.0>

# %%
# 3 lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
#  buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(48)

# %%
# tampilkan tipe data dari x
type(x_pt)
# Out:
# torch.Tensor

# %%
#  buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(84.)

# %%
# tampilkan tipe data dari y
type(y_pt)
# Out:
# torch.Tensor

# %%
# jumlahkan x+y
x_pt + y_pt
# Out:
# tensor(132)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(48.)
x_float_pt
# Out:
# tensor(48.)

# %%
# jumlahkan x_float dengan y
pt_sum = x_float_pt + y_pt
pt_sum
# Out:
# tensor(132.)

# %%
# tampilkan tipe data dari x_float
type(x_float_pt)
# Out:
# tensor(48.)
