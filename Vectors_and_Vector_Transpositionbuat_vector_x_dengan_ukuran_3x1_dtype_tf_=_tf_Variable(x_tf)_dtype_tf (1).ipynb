# %%
#1
import numpy as np

# %%
#buat vector x dengan ukuran 3x1
x = np.array([[48], [84], [7]])
print(f"vector x dengan ukuran 3x1 adalah {x} ")
# Out:
# vector x dengan ukuran 3x1 adalah [[48]
#  [84]
#  [ 7]]

# %%
#hitung panjang vector x
len(x)
print(f"panjang vector x adalah {len(x)}")
# Out:
# panjang vector x adalah 3

# %%
#tampilkan ukuran vector x
x.shape
print(f"ukuran vector x adalah {x.shape}")
# Out:
# ukuran vector x adalah (3, 1)

# %%
#tampilkan tipe data dari vector x
type(x)
print(f"tipe data dari vector x adalah {type(x)}")
# Out:
# tipe data dari vector x adalah <class 'numpy.ndarray'>

# %%
#akses elemen pertama dari vector x
x[0]
print(f" elemen pertama dari vector x adalh {x[0]}")
# Out:
#  elemen pertama dari vector x adalh [48]

# %%
#tampilkan tipe data elemen pertama dari vector x
type(x[0])
print(f"tipe data elemen pertama dari vector x adalah {type(x[0])}")
# Out:
# tipe data elemen pertama dari vector x adalah <class 'numpy.ndarray'>

# %%
# 2 lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
print(f"hasil transpose darivector x adalah {x_t}")
# Out:
# hasil transpose darivector x adalah [[48 84  7]]

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
print(f"ukuran dari vector x_t adalah {x_t.shape}")
# Out:
# ukuran dari vector x_t adalah (1, 3)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[48, 84, 7]])
y_t = y.T
print(f"hasil dari transpose vector y adalah {y_t}")
# Out:
# hasil dari transpose vector y adalah [[48]
#  [84]
#  [ 7]]

# %%
#tampilkan ukuran dari vector y_t
y_t.shape
print(f"ukuran dari vector y_t adalah {y_t}")
# Out:
# ukuran dari vector y_t adalah [[48]
#  [84]
#  [ 7]]

# %%
#3.lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t (PyTorch)
x_pt = torch.tensor([48, 84, 7])
x_T_pt = x_pt.T
print(f"hasil dari transpose vector x adalah {x_pt}")
# Out:
# hasil dari transpose vector x adalah tensor([48, 84,  7])
# /tmp/ipykernel_5174/1384089033.py:3: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4480.)
#   x_T_pt = x_pt.T

# %%
# tampilkan ukuran dari vector x_t(PyTorch)
x_pt.shape
print(f"ukuran dari vector x_t adalah {x_pt}")
# Out:
# ukuran dari vector x_t adalah tensor([48, 84,  7])

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t (PyTorch)
y_pt = torch.tensor([77, 48, 7])
y_T_pt = y_pt.T
print(f"hasil dari transpose vector y adalah {y_pt}")
# Out:
# hasil dari transpose vector y adalah tensor([77, 48,  7])

# %%
# tampilkan ukuran dari vector y_t (PyTorch)
y_pt.shape
print(f"ukuran dari vector y_t adalah {y_pt}")
# Out:
# ukuran dari vector y_t adalah tensor([77, 48,  7])

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t (TensorFlow)
x_tf = tf.Variable([48, 84, 7])
print(f"hasil dari transpose vector x adalah {x_tf}")
# Out:
# hasil dari transpose vector x adalah <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([48, 84,  7], dtype=int32)>

# %%
# tampilkan ukuran dari vector x_t (TensorFlow)
x_tf.shape
print(f"ukuran dari vector x_t adalah {x_tf}")
# Out:
# ukuran dari vector x_t adalah <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([48, 84,  7], dtype=int32)>

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t (TensorFlow)
y_tf = tf.Variable([77, 48, 7])
print(f"hasil dari transpose vector y adalah {y_tf}")
# Out:
# hasil dari transpose vector y adalah <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([77, 48,  7], dtype=int32)>

# %%
# tampilkan ukuran dari vector y_t  (TensorFlow)
y_tf.shape
print(f"ukuran dari vector y_t adalah {y_tf}")
# Out:
# ukuran dari vector y_t adalah <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([77, 48,  7], dtype=int32)>
